# %% [markdown]
# File handling means reading from and writing to files using Python.
#
# Common file types:
#
# .txt
# .csv
# .json
# .xlsx
#
# In Machine Learning, we often load data from files.
#
# Basic file modes
# Mode	Meaning
# r	read file
# w	write file, removes old content
# a	append file, adds new content
# x	create file, error if file exists
