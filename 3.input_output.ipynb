# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
# age = int(age)  # Convert string to integer
print(f"Hello {name}, you are {age} years old.")
# Out:
# Hello Shamima, you are 29 years old.
