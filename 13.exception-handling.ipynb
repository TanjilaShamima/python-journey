# %% [markdown]
# ValueError
# TypeError
# KeyError
# IndexError
# ZeroDivisionError
# FileNotFoundError
# AttributeError

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print(result)
except ValueError:
    print("Please enter a valid integer")
except ZeroDivisionError:
    print("Number cannot be zero")
# Out:
# Number cannot be zero

# %%
try:
    file = open("data.txt", "r")
except FileNotFoundError:
    print("File not found")
finally:
    print("Operation completed")
# Out:
# Operation completed <_io.TextIOWrapper name='data.txt' mode='r' encoding='UTF-8'>
