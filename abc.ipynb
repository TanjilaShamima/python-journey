# %%
dict = {'a': 1, 'b': 2, 'c': 3 }
dict.pop('b')

del dict['a']

print(dict)
# Out:
# {'c': 3}

# %%
print({'a': 1, 'b': 2}.keys())
# Out:
# dict_keys(['a', 'b'])

# %%
x = [1, 2, 3, 2, 4]
x.remove(4)
x.pop()
print(x)
# Out:
# [1, 2, 3]

# %%
nums = [2, 4, 6, 8, 10]
nums[2] = nums[2] * nums[0]
print(nums)
# Out:
# [2, 4, 12, 8, 10]

# %%
for i in range(5, 0, -1):
    if i%2 == 0:
        continue
    if i== 3:
        break
    print(i, end="")
# Out:
# 5

# %%
x = 5
if x > 3:
    print("A")
elif x > 1:
    print("B")
else:
    print("C")
# Out:
# A

# %%
print("Hello World!")
# Out:
# Hello World!
